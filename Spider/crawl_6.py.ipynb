# %%
import requests
from bs4 import BeautifulSoup

# %%
headers={
        "User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 13_2_3 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.0.3 Mobile/15E148 Safari/604.1"
}

# %%
def get_html():
    res=requests.get('https://s.weibo.com/top/summary',headers=headers)
    return res.text

# %%
html=get_html()
html
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n    <meta name="viewport" content="initial-scale=1,maximum-scale=1,user-scalable=no">\n    <meta name="format-detection" content="telephone=no">\n    <title>微博搜索</title>\n    <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/h5/css/global.css?version=202102051814" rel="stylesheet"/>\n    <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/h5/css/module.css?version=202102051814" rel="stylesheet"/>\n    <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/h5/css/page.css?version=202102051814" rel="stylesheet"/>\n</head>\n\n<body>\n<div class="wrap hotrank">\n    <a href="/"><img src="//simg.s.weibo.com/20180201141807_searchtopimg750-350.jpg" class="banner" /></a>\n    <ul class="m-nav">\n        <li><a href="/top/summary?cate=realtimehot" class="cur">热搜榜</a></li>\n        <li><a href="/top/summary?cate=topicband" >话题榜</a></li>\n        <li><a href="/top/summary?cate=soci
# ...

# %%
soup=BeautifulSoup(html,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>微博搜索</title>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/h5/css/global.css?version=202102051814" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/h5/css/module.css?version=202102051814" rel="stylesheet"/>
# <link href="//img.t.sinajs.cn/t4/appstyle/searchpc/css/h5/css/page.css?version=202102051814" rel="stylesheet"/>
# </head>
# <body>
# <div class="wrap hotrank">
# <a href="/"><img class="banner" src="//simg.s.weibo.com/20180201141807_searchtopimg750-350.jpg"/></a>
# <ul class="m-nav">
# <li><a class="cur" href="/top/summary?cate=realtimehot">热搜榜</a></li>
# <li><a href="/top/summary?cate=topicband">话题榜</a></li>
# <li><a href="/top/summary?cate=socialevent">新时代</a></li>
# ...

# %%
data=soup.find(name='section')
data
# Out:
# <section class="list">
# <h1 class="title">实时热点，每分钟更新一次</h1>
# <ul class="list_a">
# <li>
# <a href="/weibo?q=%23%E5%85%A8%E5%9B%BD%E8%84%B1%E8%B4%AB%E6%94%BB%E5%9D%9A%E6%80%BB%E7%BB%93%E8%A1%A8%E5%BD%B0%E5%A4%A7%E4%BC%9A%23&amp;Refer=new_time">
# <i class="icon icon_pinned"></i>
# <span>全国脱贫攻坚总结表彰大会</span>
# <i class="icon icon_hot"></i>
# </a>
# </li>
# <li>
# <a href="/weibo?q=%23%E5%92%B8%E7%B4%A0%E5%AA%9B%E9%99%88%E5%8D%8E%E5%88%86%E6%89%8B%23&amp;Refer=top">
# <strong class="hot">1</strong>
# <span>咸素媛陈华分手<em>1164398</em> </span>
# </a>
# </li>
# <li>
# <a href="/weibo?q=%23%E4%B8%8A%E6%B5%B7%E6%B5%B7%E5%85%B3%E6%9F%A5%E8%8E%B7406%E5%8F%AA%E6%B4%BB%E4%BD%93%E8%9A%82%E8%9A%81%23&amp;Refer=top">
# <strong class="hot">2</strong>
# <span>上海海关查获406只活体蚂蚁<em>738654</em> </span>
# </a>
# </li>
# <li>
# <a href="/weibo?q=V%E5%8A%9B%E5%85%AC%E7%9B%8A%E8%AE%A1%E5%88%92&amp;Refer=top">
# <strong class="hot">3</strong>
# <span>V力公益计划<em>513163</em> </span>
# </a>
# </li>
# <li>
# ...

# %%
items=data.find_all(name='a')
items
# Out:
# [<a href="/weibo?q=%23%E5%85%A8%E5%9B%BD%E8%84%B1%E8%B4%AB%E6%94%BB%E5%9D%9A%E6%80%BB%E7%BB%93%E8%A1%A8%E5%BD%B0%E5%A4%A7%E4%BC%9A%23&amp;Refer=new_time">
#  <i class="icon icon_pinned"></i>
#  <span>全国脱贫攻坚总结表彰大会</span>
#  <i class="icon icon_hot"></i>
#  </a>,
#  <a href="/weibo?q=%23%E5%92%B8%E7%B4%A0%E5%AA%9B%E9%99%88%E5%8D%8E%E5%88%86%E6%89%8B%23&amp;Refer=top">
#  <strong class="hot">1</strong>
#  <span>咸素媛陈华分手<em>1164398</em> </span>
#  </a>,
#  <a href="/weibo?q=%23%E4%B8%8A%E6%B5%B7%E6%B5%B7%E5%85%B3%E6%9F%A5%E8%8E%B7406%E5%8F%AA%E6%B4%BB%E4%BD%93%E8%9A%82%E8%9A%81%23&amp;Refer=top">
#  <strong class="hot">2</strong>
#  <span>上海海关查获406只活体蚂蚁<em>738654</em> </span>
#  </a>,
#  <a href="/weibo?q=V%E5%8A%9B%E5%85%AC%E7%9B%8A%E8%AE%A1%E5%88%92&amp;Refer=top">
#  <strong class="hot">3</strong>
#  <span>V力公益计划<em>513163</em> </span>
#  </a>,
# ...

# %%
items[0]
# Out:
# <a href="/weibo?q=%23%E5%85%A8%E5%9B%BD%E8%84%B1%E8%B4%AB%E6%94%BB%E5%9D%9A%E6%80%BB%E7%BB%93%E8%A1%A8%E5%BD%B0%E5%A4%A7%E4%BC%9A%23&amp;Refer=new_time">
# <i class="icon icon_pinned"></i>
# <span>全国脱贫攻坚总结表彰大会</span>
# <i class="icon icon_hot"></i>
# </a>

# %%
items[0].find(attrs={'class':'hot'}).text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-cc5eb3cdaf19> in <module>
# ----> 1 items[0].find(attrs={'class':'hot'}).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
items[0].find(name='span').text
# Out:
# '全国脱贫攻坚总结表彰大会'

# %%
items[1].find(attrs={'class':'hot'}).text
# Out:
# '1'

# %%
items[1].find(name='span').text
# Out:
# '咸素媛陈华分手1164398 '

# %%
items[1].find(name='em').text
# Out:
# '1164398'
